# %%
import pymysql

# %%
help(pymysql.connect)
# Out:
# Help on class Connection in module pymysql.connections:
#
# class Connection(builtins.object)
#  |  Connection(*, user=None, password='', host=None, database=None, unix_socket=None, port=0, charset='', sql_mode=None, read_default_file=None, conv=None, use_unicode=True, client_flag=0, cursorclass=<class 'pymysql.cursors.Cursor'>, init_command=None, connect_timeout=10, read_default_group=None, autocommit=False, local_infile=False, max_allowed_packet=16777216, defer_connect=False, auth_plugin_map=None, read_timeout=None, write_timeout=None, bind_address=None, binary_prefix=False, program_name=None, server_public_key=None, ssl=None, ssl_ca=None, ssl_cert=None, ssl_disabled=None, ssl_key=None, ssl_verify_cert=None, ssl_verify_identity=None, compress=None, named_pipe=None, passwd=None, db=None)
#  |
#  |  Representation of a socket with a mysql server.
#  |
#  |  The proper way to get an instance of this class is to call
#  |  connect().
#  |
# ...

# %%
con = pymysql.connect(host="encore.cluster-cd9ecw5piy57.ap-northeast-2.rds.amazonaws.com",
                user='admin', password='newjeans', db='encore')

# %%
cur = con.cursor()

# %%
import pandas as pd

# %%
pd.read_sql_query("select * from starbucks2", con)
# Out:
# c:\Users\Playdata\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#          s_name        tel           fax sido_code sido_name gugun_code  \
# 0       역삼아레나빌딩  1522-3232   02-568-3763        01        서울       0101
# 1        논현역사거리  1522-3232  02-3442-3673        01        서울       0101
# 2       신사역성일빌딩  1522-3232   02-547-3859        01        서울       0101
# 3        국기원사거리  1522-3232   02-568-3669        01        서울       0101
# 4       대치재경빌딩R  1522-3232   02-568-3705        01        서울       0101
# ...         ...        ...           ...       ...       ...        ...
# 3567       세종청사  1522-3232  044-867-8706        17        세종       1701
# 3568       세종아름  1522-3232  044-862-4025        17        세종       1701
# ...
