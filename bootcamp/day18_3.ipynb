# %% [markdown]
# - 통계, 데이터 중심의 지표

# %%
import numpy as np
import pandas as pd

# Jupyter Notebook의 출력을 소수점 이하 3자리로 제한
# %precision 3
# Out:
# '%.3f'

# %%
df = pd.read_csv('./ch2_scores_em.csv', index_col='student number')
# df의 처음 5행을 표시
df.head() #head가 있으면 tail도 항상 존재
# Out:
#                 english  mathematics
# student number
# 1                    42           65
# 2                    69           80
# 3                    56           63
# 4                    41           63
# 5                    57           76

# %%
df['english'].values[:10] #df['english]는 시리즈 이거는 넘파이상태
# Out:
# array([42, 69, 56, 41, 57, 48, 65, 49, 65, 58], dtype=int64)

# %%
scores = np.array(df['english'])[:10]
scores
# Out:
# array([42, 69, 56, 41, 57, 48, 65, 49, 65, 58], dtype=int64)

# %%
scores_df = pd.DataFrame({'score':scores}, # score를 컬럼명으로
                         index=pd.Index(['A', 'B', 'C', 'D', 'E',
                                         'F', 'G', 'H', 'I', 'J'],
                                        name='student'))
scores_df
# Out:
#          score
# student
# A           42
# B           69
# C           56
# D           41
# E           57
# F           48
# G           65
# H           49
# I           65
# J           58

# %% [markdown]
# - 평균값

# %%
sum(scores) / len(scores)
# Out:
# 55.0

# %%
np.mean(scores) #numpy의 mean()을 사용하면 평균 구할 수 있음
# Out:
# 55.0

# %%
scores_df.mean() #Pandas의 mean()함수도 평균 계산
# Out:
# score    55.0
# dtype: float64

# %%
np.median(scores) # 중앙값
# Out:
# 56.5

# %% [markdown]
# - 최빈값

# %%
pd.Series([1, 1, 1, 2, 2, 3]).mode()
# Out:
# 0    1
# dtype: int64

# %% [markdown]
# - 편차
# > 각 데이터가 평균으로부터 어느정도 떨어져 있는가

# %%
sum(deviation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11636\3164303562.py in <module>
# ----> 1 sum(deviation)
#
# NameError: name 'deviation' is not defined

# %% [markdown]
# - 분산
# >> 편차의 평균은 항상 0이 되므로 편차의 제곱을 이용한 분산(Variance) 사용
# >> var() 함수에는 ddor=0으로 기본설정
# >> 불편분산은 ddof=1일 때 해당 (자유도 1)
# >> numpy와 pandas의 기본 설정 값이 다르기 때문에 주의

# %%
np.mean(deviation*2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11636\4243345283.py in <module>
# ----> 1 np.mean(deviation*2)
#
# NameError: name 'deviation' is not defined

# %%
np.var(scores)
# Out:
# 86.0

# %%
scores_df.var()
# Out:
# score    95.555556
# dtype: float64

# %%
help(pd.DataFrame.var)
# Out:
# Help on function var in module pandas.core.generic:
#
# var(self, axis=None, skipna=True, level=None, ddof=1, numeric_only=None, **kwargs)
#     Return unbiased variance over requested axis.
#
#     Normalized by N-1 by default. This can be changed using the ddof argument.
#
#     Parameters
#     ----------
#     axis : {index (0), columns (1)}
#     skipna : bool, default True
#         Exclude NA/null values. If an entire row/column is NA, the result
#         will be NA.
#     level : int or level name, default None
#         If the axis is a MultiIndex (hierarchical), count along a
#         particular level, collapsing into a Series.
#     ddof : int, default 1
#         Delta Degrees of Freedom. The divisor used in calculations is N - ddof,
#         where N represents the number of elements.
#     numeric_only : bool, default None
#         Include only float, int, boolean columns. If None, will attempt to use
# ...

# %% [markdown]
# - 불편분산 테스트

# %%
import random

# %%
df.shape
# Out:
# (50, 2)

# %%
df['english'].var()
# Out:
# 96.036

# %%
cnt = 0
for x in range(10000) :
    if np.var(random.choices(df['english'].values, k= 20)) < 96.036 :
        cnt += 1
    # print(f" {x} -> {np.var(random.choices(df['english'].values, k= 20))} " )

# %%
cnt
# Out:
# 6114

# %%
df['english']
# Out:
# student number
# 1     42
# 2     69
# 3     56
# 4     41
# 5     57
# 6     48
# 7     65
# 8     49
# 9     65
# 10    58
# 11    70
# 12    47
# 13    51
# 14    64
# 15    62
# 16    70
# 17    71
# 18    68
# 19    73
# 20    37
# 21    65
# 22    65
# 23    61
# 24    52
# 25    57
# 26    57
# 27    75
# 28    61
# 29    47
# 30    54
# 31    66
# 32    54
# 33    54
# 34    42
# 35    37
# 36    79
# 37    56
# 38    62
# 39    62
# 40    55
# 41    63
# 42    57
# 43    57
# 44    67
# 45    55
# 46    45
# 47    66
# 48    55
# 49    64
# 50    66
# Name: english, dtype: int64

# %% [markdown]
# - 표준편차
# > 분산에 제곱근을 취한 표준편차

# %%
np.sqrt(np.var(scores, ddof=0))
# Out:
# 9.273618495495704

# %%
np.std(scores,ddof=0)
# Out:
# 9.273618495495704

# %% [markdown]
# - 데이터의 지표 정리

# %%
pd.Series(scores).describe()
# Out:
# count    10.000000
# mean     55.000000
# std       9.775252
# min      41.000000
# 25%      48.250000
# 50%      56.500000
# 75%      63.250000
# max      69.000000
# dtype: float64

# %%
import pickle
import pandas as pd

with open("./source/kbo_player.pkl", "rb") as f :
    data = pickle.load(f)

kbo = pd.DataFrame(data)

# %%
kbo
# Out:
#      선수명    등번호           생년월일        포지션       신장/체중  \
# 0    강매성  No.95  2003년 06월 08일   투수(우투우타)  187cm/94kg
# 1    고명준   No.6  2002년 07월 08일  내야수(우투우타)  185cm/94kg
# 2    고효준  No.65  1983년 02월 08일   투수(좌투좌타)  179cm/81kg
# 3    김강민   No.0  1982년 09월 13일  외야수(우투우타)  182cm/87kg
# 4    김건우  No.59  2002년 07월 12일   투수(좌투좌타)  185cm/88kg
# ..   ...    ...            ...        ...         ...
# 824  하주석  No.16  1994년 02월 25일  내야수(우투좌타)  184cm/84kg
# 825  한승주  No.59  2001년 03월 17일   투수(우투우타)  184cm/82kg
# 826  허관회  No.26  1999년 02월 12일   포수(우투우타)  176cm/83kg
# 827  허인서  No.64  2003년 07월 11일   포수(우투우타)  182cm/93kg
# 828  황영국  No.58  1995년 12월 26일   투수(좌투좌타)  185cm/83kg
#
#                               경력   입단 계약금       연봉                 지명순위  입단년도  \
# 0            상탄초(일산동구리틀)-개군중-공주고   5000만원   3000만원  22 SSG 2차 6라운드 52순위
# 1                 서원초-세광중-세광고-SK   9000만원   3000만원   21 SK 2차 2라운드 18순위  21SK
# 2    서원초-세광중-세광고-롯데-SK-KIA-롯데-LG  11000만원   4000만원    02 롯데 2차 1라운드 6순위  02롯데
# ...

# %%
kbo.loc[kbo['Team'] == "고양 히어로즈",'Team'] = "키움 히어로즈" #고양이란 컬럼을 키움으로 바꿔줘
# == kbo[kbo['Team].str.find("고양") > -1]

# %%
kbo.value_counts('Team')
# Out:
# Team
# LG 트윈스      89
# 두산 베어스      88
# KIA 타이거즈    84
# KT 위즈       83
# NC 다이노스     83
# 한화 이글스      83
# SSG 랜더스     82
# 삼성 라이온즈     80
# 키움 히어로즈     79
# 롯데 자이언츠     78
# dtype: int64

# %%
kbo[kbo['연봉'] == ""]
# Out:
#      선수명     등번호           생년월일        포지션       신장/체중                    경력  \
# 243  정은재  No.102  1991년 12월 31일   투수(우투우타)  192cm/92kg        화곡초-덕수중-선린인터넷고
# 336  황성빈   No.40  1997년 12월 19일  외야수(우투좌타)  175cm/73kg  관산초-안산중앙중-소래고-경남대-롯데
#
#     입단 계약금 연봉                지명순위 입단년도     Team
# 243                                      두산 베어스
# 336            20 롯데 2차 5라운드 44순위       롯데 자이언츠

# %%
kbo[kbo['연봉'].apply(lambda x : x[-2:] in ['달러'])].value_counts('Team')
# Out:
# Team
# KIA 타이거즈    3
# KT 위즈       3
# LG 트윈스      3
# NC 다이노스     3
# SSG 랜더스     3
# 두산 베어스      3
# 롯데 자이언츠     3
# 삼성 라이온즈     3
# 키움 히어로즈     3
# 한화 이글스      3
# dtype: int64

# %%
import requests

# %%
url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"

# %%
payload = {"ajax" : "true",
"curCd" : "",
"tmpInqStrDt" : "2023-03-06",
"pbldDvCd" : "0",
"pbldSqn" : "",
"hid_key_data" : "",
"inqStrDt" : "20230306",
"inqKindCd" : "1",
"hid_enc_data" : "",
"requestTarget" : "searchContentDiv",}

# %%
r = requests.post(url, data=payload)

# %%
hana = pd.read_html(r.text)[0]

# %%
hana
# Out:
#                  통화       현찰                              송금          T/C사실때  \
#                  통화     사실 때            파실 때            보낼 때     받을 때 T/C사실때
#                  통화       환율 Spread       환율 Spread     보낼 때     받을 때 T/C사실때
# 0            미국 USD  1320.20   1.75  1274.80   1.75  1310.20  1284.80    0.0
# 1      일본 JPY (100)   972.20   1.75   938.76   1.75   964.84   946.12    0.0
# 2            유로 EUR  1408.94   1.99  1353.96   1.99  1395.26  1367.64    0.0
# 3            중국 CNY   196.66   5.00   177.94   5.00   189.17   185.43    0.0
# 4            홍콩 HKD   168.54   1.97   162.04   1.97   166.94   163.64    0.0
# 5            태국 THB    39.53   5.00    35.40   6.00    38.02    37.28    0.0
# 6            대만 TWD    47.95  13.10    38.16  10.00     0.00     0.00    0.0
# 7           필리핀 PHP    26.02  10.00    21.72   8.20    23.89    23.43    0.0
# 8          싱가포르 SGD   984.14   1.99   945.74   1.99   974.58   955.30    0.0
# ...

# %%
for x in hana.columns :
    print(x)
# Out:
# ('통화', '통화', '통화')
# ('현찰', '사실 때', '환율')
# ('현찰', '사실 때', 'Spread')
# ('현찰', '파실 때', '환율')
# ('현찰', '파실 때', 'Spread')
# ('송금', '보낼 때', '보낼 때')
# ('송금', '받을 때', '받을 때')
# ('T/C사실때', 'T/C사실때', 'T/C사실때')
# ('외화수표파실때', '외화수표파실때', '외화수표파실때')
# ('매매기준율', '매매기준율', '매매기준율')
# ('환가료율', '환가료율', '환가료율')
# ('미화환산율', '미화환산율', '미화환산율')

# %%
hana.columns = ["_".join(list(set(x))) for x in hana.columns]

# %%
hana.iloc[0,3]
# Out:
# 1274.8

# %%
hana.loc[0, '파실 때_현찰_환율']
# Out:
# 1274.8

# %%
hana.loc[hana.통화.str.find("USD") > -1, "파실 때_현찰_환율"]
# Out:
# 0    1274.8
# Name: 파실 때_현찰_환율, dtype: float64

# %%
hana
# Out:
#                  통화  환율_현찰_사실 때  현찰_사실 때_Spread  파실 때_현찰_환율  파실 때_현찰_Spread  \
# 0            미국 USD     1320.20            1.75     1274.80            1.75
# 1      일본 JPY (100)      972.20            1.75      938.76            1.75
# 2            유로 EUR     1408.94            1.99     1353.96            1.99
# 3            중국 CNY      196.66            5.00      177.94            5.00
# 4            홍콩 HKD      168.54            1.97      162.04            1.97
# 5            태국 THB       39.53            5.00       35.40            6.00
# 6            대만 TWD       47.95           13.10       38.16           10.00
# 7           필리핀 PHP       26.02           10.00       21.72            8.20
# 8          싱가포르 SGD      984.14            1.99      945.74            1.99
# 9            호주 AUD      893.46            1.97      858.94            1.97
# 10    베트남 VND (100)        6.12           11.80        4.84           11.80
# ...

# %%
def get_exchane(date_,currency,type_) :
    """
    date_ : 날짜, 날짜는 yyyy-mm-dd 형식으로 입력
    currency : 화폐 코드
    type_ : 0 사실 때, 1 파실 때 리턴
    """

    pass

# %%
def get_exchane(date_,currency,type_) :
    if
