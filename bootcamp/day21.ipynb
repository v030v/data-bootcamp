# %%
import pandas as pd
import os

# %%
total = [pd.read_csv("./subway/{}".format(x), encoding='euc-kr') for x in os.listdir("./subway/")]

# %%
len(total)
# Out:
# 12

# %%
for df in total :
    print(df.columns)
    print("-"*50)
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')
# --------------------------------------------------
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')
# --------------------------------------------------
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
# ...

# %%
for idx, df in enumerate(total):
    print(idx+1, df.columns)
    print("-"*50)
# Out:
# 1 Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')
# --------------------------------------------------
# 2 Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04'],
#       dtype='object')
# --------------------------------------------------
# 3 Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
# ...

# %%
df1 = pd.concat(total[:5])

# %%
# tmp= pd.concat(total[:5], ignore_index=True)

# %%
df1
# Out:
#                날짜   호선        역명 구 분   할인  04 ~ 05  05 ~ 06  06 ~ 07  07 ~ 08  \
# 0      2016-01-01  1호선  서울역(150)  승차   일반       44      298      243      490
# 1      2016-01-01  1호선  서울역(150)  승차  초등생        1        4        0        4
# 2      2016-01-01  1호선  서울역(150)  승차  청소년        8       33       15       16
# 3      2016-01-01  1호선  서울역(150)  승차  대학생        0        0        0        0
# 4      2016-01-01  1호선  서울역(150)  승차   우대       11       70       78       65
# ...           ...  ...       ...  ..  ...      ...      ...      ...      ...
# 52981  2016-05-31  4호선  남태령(434)  승차   우대        0        9       11       10
# 52982  2016-05-31  4호선  남태령(434)  하차   일반        0        0       78      106
# 52983  2016-05-31  4호선  남태령(434)  하차  초등생        0        0        0       14
# 52984  2016-05-31  4호선  남태령(434)  하차  청소년        0        0        1      149
# 52985  2016-05-31  4호선  남태령(434)  하차   우대        0        1       13       21
#
# ...

# %%
import re 
p = re.compile("\(([0-9]+)\)") #\(실제 괄호 나머지 명령어, 괄호 없애려고함
df1['역번호'] = df1['역명'].apply(lambda x : p.findall(x)[0])

# %%
p.findall("서울역(150)")
# Out:
# ['150']

# %%
# %%time # 시간측정
# for idx, row in tmp.iterrows():
#     tmp.loc[idx, '역번호'] = p.findall(row.역명)[0]

# %%
df1.columns
# Out:
# Index(['날짜', '호선', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
#        '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
#        '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
#        '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
#        '01 ~ 02', '02 ~ 03', '03 ~ 04', '역번호'],
#       dtype='object')

# %%
df1 = df1[['날짜', '호선', '역번호', '역명', '구 분', '할인', '04 ~ 05', '05 ~ 06', '06 ~ 07',
       '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13',
       '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19',
       '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01',
       '01 ~ 02', '02 ~ 03', '03 ~ 04', ]] #컬럼 순서 변경

# %%
p.sub("", "서울역(150)")
# Out:
# '서울역'

# %%
df1['역명'] = df1['역명'].apply(lambda x : p.sub("", x))

# %%
df1.columns = df1.columns.str.replace(" ", "")

# %%
df1_1 = df1.groupby(['날짜', '호선', '역번호', '역명', '구분'],
           as_index=False).sum().copy()

# %%
df1_1.drop('호선', axis=1, inplace=True)

# %%
df1_1.drop(['02~03','03~04','04~05'], axis=1, inplace=True)

# %%
df1_1.head(3)
# Out:
#            날짜  역번호   역명  구분  05~06  06~07  07~08  08~09  09~10  10~11  ...  \
# 0  2016-01-01  150  서울역  승차    405    339    584   1144   1723   2087  ...
# 1  2016-01-01  150  서울역  하차    341   1637   1753   1856   2438   2425  ...
# 2  2016-01-01  151   시청  승차     98    127    110    191    298    582  ...
#
#    16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  00~01  01~02
# 0   3554   3200   3076   2519   2281   2398   2056    996     58      0
# 1   3108   2656   2134   1859   1394   1344   1056    612    222      0
# 2   1339   1458   1499   1383   1284   1198    675    375      9      0
#
# [3 rows x 25 columns]

# %%
df2 = pd.concat(total[5:-1]) # 6월 데이터부터~ 11월까지

# %%
df2['역번호'] = df2.역명.apply(lambda x : p.findall(x)[0])

# %%
df2['역명'] = df2.역명.apply(lambda x : p.sub("",x))

# %%
set(df1_1.columns) - set(df2.columns)
# Out:
# set()

# %%
len(set(df2.columns) & set(df1_1.columns))
# Out:
# 25

# %%
df1_1.columns.size
# Out:
# 25

# %%
df1_1[df1_1['02~03'] > 0].head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Playdata\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\Playdata\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\Playdata\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '02~03'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pd.concat([df1_1, df2]).shape
# Out:
# (79730, 25)

# %%
df3 = total[-1].copy()

# %%
df3['역번호'] = df3.역명.apply(lambda x : p.findall(x)[0])
df3['역명'] = df3.역명.apply(lambda x : p.sub("", x))

# %%
df3.columns = df3.columns.str.replace("시", "")

# %%
len(set(df2.columns) & set(df3.columns))
# Out:
# 25

# %%
subway = pd.concat([df1_1, df2, df3], ignore_index=True)

# %%
subway.isnull().sum().sum()
# Out:
# 0

# %%
subway_ana = pd.DataFrame(subway.groupby(['역명', '구분']).sum().apply(sum, axis=1), columns=['총합'])

# %%
subway_ana.reset_index(inplace=True)

# %%
"{:,}".format(subway_ana.총합.sum())
# Out:
# '2,193,640,583'

# %%
subway_ana.sort_values('총합',ascending=False).head(10)
# Out:
#        역명  구분        총합
# 3      강남  하차  36727247
# 2      강남  승차  36262673
# 176    잠실  승차  31080170
# 215  홍대입구  하차  29943407
# 177    잠실  하차  28879208
# 95    서울역  하차  28164843
# 214  홍대입구  승차  28015621
# 82     사당  승차  27432213
# 83     사당  하차  27385938
# 94    서울역  승차  27316668

# %%
subway_ana.query('구분 == "승차"').sort_values('총합',ascending=False).head(10)
# Out:
#           역명  구분        총합
# 2         강남  승차  36262673
# 176       잠실  승차  31080170
# 214     홍대입구  승차  28015621
# 82        사당  승차  27432213
# 94       서울역  승차  27316668
# 120       신림  승차  26680680
# 16   구로디지털단지  승차  23104249
# 118      신도림  승차  22965725
# 12     고속터미널  승차  20905177
# 86        삼성  승차  20538267

# %%
홍대 = subway[subway.역명 == '홍대입구'].copy()

# %%
#월별 홍대 승하차 바차트로 보여줘
홍대['월'] = 홍대.날짜.apply(lambda x : x.split("-")[1])

# %%
홍대승하차 = 홍대.groupby(['월','구분']).sum().apply(sum, axis=1)

# %%
홍대승하차 = pd.DataFrame(홍대승하차, columns=['총합'])

# %%
홍대승하차.index #멀티인덱스
# Out:
# MultiIndex([('01', '승차'),
#             ('01', '하차'),
#             ('02', '승차'),
#             ('02', '하차'),
#             ('03', '승차'),
#             ('03', '하차'),
#             ('04', '승차'),
#             ('04', '하차'),
#             ('05', '승차'),
#             ('05', '하차'),
#             ('06', '승차'),
#             ('06', '하차'),
#             ('07', '승차'),
#             ('07', '하차'),
#             ('08', '승차'),
#             ('08', '하차'),
#             ('09', '승차'),
#             ('09', '하차'),
#             ('10', '승차'),
#             ('10', '하차'),
#             ('11', '승차'),
#             ('11', '하차'),
#             ('12', '승차'),
#             ('12', '하차')],
#            names=['월', '구분'])

# %%
홍대승하차.reset_index(inplace=True)

# %%
import seaborn as sns # 통계에 특화된 시각화

# %%
sns.barplot( x='월', y='총합', data = 홍대승하차, hue='구분')
# Out:
# <AxesSubplot:xlabel='월', ylabel='총합'>
# c:\Users\Playdata\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
subway
# Out:
#                날짜  역번호   역명  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0      2016-01-01  150  서울역  승차    405    339    584   1144   1723   2087
# 1      2016-01-01  150  서울역  하차    341   1637   1753   1856   2438   2425
# 2      2016-01-01  151   시청  승차     98    127    110    191    298    582
# 3      2016-01-01  151   시청  하차     68    306    554    939    689    665
# 4      2016-01-01  152   종각  승차    677    341    234    296    335    419
# ...           ...  ...  ...  ..    ...    ...    ...    ...    ...    ...
# 87103  2016-12-29  434  남태령  하차      2     26    189    238     68     64
# 87104  2016-12-30  434  남태령  승차     18     23    125    165    111     80
# 87105  2016-12-30  434  남태령  하차      4     39     75    154     61     30
# 87106  2016-12-31  434  남태령  승차     16     22     19     93     81     71
# 87107  2016-12-31  434  남태령  하차      0     17     23     40     26     55
#
#        ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  00~01  \
# ...

# %%
for text in [x.replace("~", "_") for x in subway.columns[4:]] :
    print (f"{text} INT DEFAULT NULL,")
# Out:
# 05_06 INT DEFAULT NULL,
# 06_07 INT DEFAULT NULL,
# 07_08 INT DEFAULT NULL,
# 08_09 INT DEFAULT NULL,
# 09_10 INT DEFAULT NULL,
# 10_11 INT DEFAULT NULL,
# 11_12 INT DEFAULT NULL,
# 12_13 INT DEFAULT NULL,
# 13_14 INT DEFAULT NULL,
# 14_15 INT DEFAULT NULL,
# 15_16 INT DEFAULT NULL,
# 16_17 INT DEFAULT NULL,
# 17_18 INT DEFAULT NULL,
# 18_19 INT DEFAULT NULL,
# 19_20 INT DEFAULT NULL,
# 20_21 INT DEFAULT NULL,
# 21_22 INT DEFAULT NULL,
# 22_23 INT DEFAULT NULL,
# 23_24 INT DEFAULT NULL,
# 00_01 INT DEFAULT NULL,
# 01_02 INT DEFAULT NULL,

# %%
# CREATE TABLE subway(
#     date_ Date NOT NULL, # 필수 값
#     code_ int NOT NULL,
#     station varchar(20) NOT NULL,
#     gubun varchar(10) NOT NULL,
#     05_06 INT DEFAULT NULL,
#     06_07 INT DEFAULT NULL,
#     07_08 INT DEFAULT NULL,
#     08_09 INT DEFAULT NULL,
#     09_10 INT DEFAULT NULL,
#     10_11 INT DEFAULT NULL,
#     11_12 INT DEFAULT NULL,
#     12_13 INT DEFAULT NULL,
#     13_14 INT DEFAULT NULL,
#     14_15 INT DEFAULT NULL,
#     15_16 INT DEFAULT NULL,
#     16_17 INT DEFAULT NULL,
#     17_18 INT DEFAULT NULL,
#     18_19 INT DEFAULT NULL,
#     19_20 INT DEFAULT NULL,
#     20_21 INT DEFAULT NULL,
#     21_22 INT DEFAULT NULL,
#     22_23 INT DEFAULT NULL,
#     23_24 INT DEFAULT NULL,
#     00_01 INT DEFAULT NULL,
#     01_02 INT DEFAULT NULL
#     PRIMARY KEY('date_', 'code_', 'station', 'gubun')   
# )

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://admin:newjeans@encore.cluster-cd9ecw5piy57.ap-northeast-2.rds.amazonaws.com/encore")

# %%
subway.head(1)
# Out:
#         date_  code_ station gubun  05_06  06_07  07_08  08_09  09_10  10_11  \
# 0  2016-01-01    150     서울역    승차    405    339    584   1144   1723   2087
#
#    ...  16_17  17_18  18_19  19_20  20_21  21_22  22_23  23_24  00_01  01_02
# 0  ...   3554   3200   3076   2519   2281   2398   2056    996     58      0
#
# [1 rows x 25 columns]

# %%
subway.to_sql(subway, if_exists='append', con= engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12216\3765208339.py in <module>
# ----> 1 subway.to_sql(subway, if_exists='append', con= engine, index=False)
#
# c:\Users\Playdata\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# c:\Users\Playdata\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# ...

# %%
subway = pd.read_sql_query("select * from subway", con=engine)

# %%
subway.columns = pd.read_sql_query("desc subway", con=engine)['Field'].tolist()

# %%
master = pd.read_csv("./서울교통공사 노선별 지하철역 정보.csv", encoding='cp949')

# %%
master.shape
# Out:
# (767, 7)

# %%
master[master.전철역명.str.find("강남") > -1]
# Out:
#     전철역코드  전철역명           전철명명(영문)     호선  외부코드 전철명명(중문) 전철명명(일문)
# 83   1849  강남구청  Gangnam-gu Office  수인분당선  K213     江南區廳     江南區廳
# 291  2732  강남구청  Gangnam-gu Office   07호선   730     江南區廳     江南區廳
# 398  0222    강남            Gangnam   02호선   222       江南       江南
# 637  4307    강남            Gangnam   신분당선    D7       江南       江南
# 680  4502   강남대      Kangnam Univ.  용인경전철  Y111      江南大    カンナムデ

# %%
subway.code_ = subway.code_.apply(lambda x : str(x).zfill(4)) #문자열을 네자리로 바꿔서,,,?

# %%
master.전철역코드
# Out:
# 0      0244
# 1      0245
# 2      0250
# 3      0336
# 4      0428
#        ...
# 762    0159
# 763    0200
# 764    0201
# 765    0202
# 766    0300
# Name: 전철역코드, Length: 767, dtype: object

# %%
master.head(1)
# Out:
#   전철역코드 전철역명 전철명명(영문)    호선   외부코드 전철명명(중문) 전철명명(일문)
# 0  0244   용답  Yongdap  02호선  211-1       龍踏       龍踏

# %%
subway.head(1)
# Out:
#         date_ code_ station gubun  05_06  06_07  07_08  08_09  09_10  10_11  \
# 0  2016-01-01  0150     서울역    승차    405    339    584   1144   1723   2087
#
#    ...  16_17  17_18  18_19  19_20  20_21  21_22  22_23  23_24  00_01  01_02
# 0  ...   3554   3200   3076   2519   2281   2398   2056    996     58      0
#
# [1 rows x 25 columns]

# %%
pd.merge(subway, master[['호선','전철역코드']], left_on='code_', right_on='전철역코드', how='left')
# Out:
#             date_ code_ station gubun  05_06  06_07  07_08  08_09  09_10  \
# 0      2016-01-01  0150     서울역    승차    405    339    584   1144   1723
# 1      2016-01-01  0150     서울역    하차    341   1637   1753   1856   2438
# 2      2016-01-01  0151      시청    승차     98    127    110    191    298
# 3      2016-01-01  0151      시청    하차     68    306    554    939    689
# 4      2016-01-01  0152      종각    승차    677    341    234    296    335
# ...           ...   ...     ...   ...    ...    ...    ...    ...    ...
# 87103  2016-12-31  0432   총신대입구    하차     25    280    265    671    853
# 87104  2016-12-31  0433      사당    승차    319    520    643   1175   1358
# 87105  2016-12-31  0433      사당    하차     33    397    297    423    655
# 87106  2016-12-31  0434     남태령    승차     16     22     19     93     81
# 87107  2016-12-31  0434     남태령    하차      0     17     23     40     26
#
#        10_11  ...  18_19  19_20  20_21  21_22  22_23  23_24  00_01  01_02  \
# ...
